// %% [markdown]
// # Nivell 2 (màxim 2,5 punts)

// %% [markdown]
// ## Exercici 1 (1 punt)
//
// Fes un snippet que, donat un número N enter positiu, imprimeixi la suma de tots els múltiples de 3 que hi ha entre 1 i el número enter N donat.
//
// Per exemple:
//
// ```java
// int N = 15;
//
// // Els números múltiples de 3 que hi ha entre 1 i 15 són:
// // 3, 6, 9, 12, 15
//
// // 3 + 6 + 9 + 12 + 15 = 45
//
// // L'snippet ha de retonar 45
// ```

// %%
//TODO. 
int N = 15;
// valor por defecto de la suma
int suma = 0;
//bucle k empieza dese de index 1 y llega hasta N
for (int i = 1; i <= N; i++) {
    if (i % 3 == 0) { //para encontrar los multiplos de 3 entre 1 y N
        suma += i;  //suma si encuentra un multiplo
    }
}

System.out.println(suma);//imprimir el rsultado por la pantalla
// Out:
// 45

// %% [markdown]
// ## Exercici 2 (ordenació) (1,5 punts)

// %% [markdown]
// En aquest exercici implementaràs una funció que ordeni els elements d'un array, de menor a major. Treballarem amb arrays de números enters. **No està permès que utilitzis funcions o instruccions pròpies de java**.
//
// > Per a resoldre aquest exercici **és obligatori** que segueixis el següent algorisme:

// %% [markdown]
//     Buscar el mínimo elemento de la lista
//     Intercambiarlo con el primero
//     Buscar el siguiente mínimo en el resto de la lista
//     Intercambiarlo con el segundo
//
// I en general:
//
//     Buscar el mínimo elemento entre una posición i y el final de la lista
//     Intercambiar el mínimo con el elemento de la posición i
//
// _De esta manera se puede escribir el siguiente **pseudocódigo** para ordenar una lista de n elementos indexados desde el 0_:
//
// ```
// para i=0 hasta n-2
//     mínimo = i;
//     para j=i+1 hasta n-1
//         si lista[j] < lista[mínimo] entonces
//             mínimo = j
//         fin si
//     fin para
//     intercambiar(lista[i], lista[mínimo])
// fin para
// ```

// %%
//TODO
// Per a resoldre aquest exercici has de generar un array de 1000 d'enters aleatòris
// entre 0 i 20000, fent servir el codi que hi ha al nivell 1, 
// que hauràs d'ordenar de menor a major

// Crear array aleatori de 1000 elements entre 0 i 20000

//generar un array
int getRandomNumber(int min, int max) {
    int upper = max * 20; //hasta 20 mil
    Random random = new Random();
    return random.nextInt(upper - min) + min;
}

int[] createRandomIntArray(int max){
    int[] numbers = new int[max];
    for(int i = 0; i < max; i++){
        numbers[i] = getRandomNumber(0,max);
    }
    return numbers;
}

int[] numbers = createRandomIntArray(100);

//print(Arrays.toString(numbers));



int[] numbers = createRandomIntArray(1000);

// bucle para ordenar array de menor a mayor
for (int i = 0; i < numbers.length - 1; i++) {
    int minIndex = i;
    for (int j = i + 1; j < numbers.length; j++) {
        if (numbers[j] < numbers[minIndex]) {
            minIndex = j;
        }
    }
    //swap
    int temp = numbers[minIndex];
    numbers[minIndex] = numbers[i];
    numbers[i] = temp;
}

// Imprimir array
System.out.println(Arrays.toString(numbers));
// Out:
// [6, 22, 25, 31, 55, 64, 70, 89, 103, 176, 183, 193, 214, 224, 266, 273, 290, 317, 330, 330, 334, 343, 356, 381, 411, 429, 449, 456, 491, 518, 606, 658, 672, 713, 729, 768, 771, 791, 820, 821, 887, 887, 887, 893, 940, 1017, 1023, 1038, 1053, 1056, 1081, 1110, 1142, 1232, 1243, 1307, 1323, 1354, 1365, 1394, 1410, 1419, 1432, 1448, 1514, 1532, 1563, 1581, 1619, 1644, 1671, 1687, 1688, 1845, 1847, 1871, 1876, 1911, 1924, 1925, 1935, 1975, 2014, 2019, 2027, 2030, 2108, 2120, 2124, 2160, 2189, 2193, 2226, 2234, 2256, 2271, 2292, 2323, 2362, 2364, 2369, 2383, 2425, 2456, 2490, 2536, 2567, 2599, 2673, 2722, 2739, 2766, 2785, 2786, 2802, 2833, 2852, 2879, 2894, 2898, 2901, 2919, 2924, 2940, 2947, 2952, 2962, 2971, 2973, 2979, 2983, 3017, 3024, 3096, 3128, 3154, 3174, 3184, 3245, 3250, 3257, 3262, 3286, 3287, 3299, 3307, 3310, 3312, 3313, 3316, 3342, 3373, 3373, 3439, 3446, 3459, 3465, 3478, 3479, 3492, 3538, 3545, 3551, 3579, 3597, 3610, 3614, 3665, 3675, 3812, 3821, 3829, 3847, 3854, 3860, 3896, 3906, 3928, 3967, 3978, 3978, 4001, 4022, 4029, 4060, 4074, 4078, 4131, 4144, 4159, 4179, 4185, 4243, 4262, 4282, 4286, 4314, 4322, 4333, 4335, 4361, 4421, 4442, 4464, 4480, 4532, 4542, 4562, 4584, 4595, 4638, 4641, 4644, 4666, 4732, 4749, 4752, 4753, 4763, 4797, 4815, 4879, 4925, 4931, 4931, 4940, 4951, 4960, 5029, 5054, 5065, 5086, 5106, 5138, 5146, 5177, 5232, 5246, 5250, 5304, 5308, 5326, 5353, 5368, 5396, 5406, 5429, 5464, 5475, 5565, 5615, 5634, 5657, 5665, 5699, 5721, 5748, 5759, 5760, 5766, 5783, 5799, 5810, 5833, 5854, 5857, 5880, 5883, 5909, 5910, 5937, 5955, 5955, 5989, 6012, 6013, 6053, 6105, 6115, 6144, 6169, 6173, 6180, 6214, 6225, 6261, 6266, 6266, 6281, 6297, 6307, 6308, 6308, 6398, 6429, 6437, 6514, 6517, 6536, 6553, 6563, 6575, 6580, 6590, 6625, 6635, 6657, 6667, 6714, 6726, 6740, 6771, 6777, 6782, 6835, 6850, 6905, 6927, 6929, 6936, 6941, 6946, 7005, 7052, 7063, 7072, 7120, 7120, 7139, 7154, 7156, 7169, 7183, 7186, 7197, 7232, 7241, 7257, 7321, 7348, 7352, 7354, 7357, 7393, 7399, 7431, 7437, 7450, 7487, 7500, 7506, 7521, 7522, 7527, 7542, 7552, 7568, 7570, 7575, 7595, 7624, 7634, 7670, 7676, 7746, 7754, 7771, 7788, 7800, 7805, 7822, 7823, 7846, 7875, 8002, 8003, 8028, 8030, 8039, 8040, 8054, 8060, 8062, 8078, 8090, 8149, 8171, 8190, 8196, 8224, 8234, 8245, 8248, 8253, 8261, 8264, 8271, 8277, 8286, 8314, 8334, 8342, 8347, 8361, 8365, 8367, 8377, 8385, 8425, 8443, 8493, 8516, 8537, 8552, 8575, 8613, 8643, 8668, 8685, 8710, 8711, 8732, 8741, 8781, 8797, 8801, 8812, 8847, 8880, 8886, 8898, 8921, 8952, 8962, 9005, 9017, 9042, 9080, 9082, 9116, 9117, 9125, 9139, 9192, 9209, 9210, 9221, 9229, 9251, 9275, 9281, 9289, 9297, 9302, 9366, 9373, 9378, 9397, 9398, 9427, 9432, 9440, 9452, 9477, 9504, 9545, 9548, 9549, 9580, 9586, 9622, 9631, 9641, 9644, 9659, 9696, 9708, 9740, 9759, 9784, 9792, 9803, 9804, 9829, 9862, 9878, 9936, 9964, 9975, 9979, 10035, 10053, 10067, 10071, 10106, 10141, 10189, 10193, 10202, 10216, 10235, 10241, 10272, 10287, 10288, 10291, 10293, 10317, 10356, 10364, 10366, 10369, 10378, 10403, 10431, 10472, 10504, 10523, 10537, 10555, 10561, 10616, 10642, 10644, 10646, 10662, 10668, 10687, 10693, 10703, 10718, 10730, 10760, 10838, 10909, 10937, 10992, 11028, 11037, 11039, 11046, 11061, 11067, 11073, 11089, 11091, 11131, 11198, 11209, 11223, 11228, 11229, 11257, 11257, 11297, 11309, 11311, 11325, 11365, 11366, 11405, 11409, 11428, 11431, 11436, 11455, 11506, 11511, 11515, 11550, 11572, 11602, 11617, 11637, 11648, 11678, 11701, 11802, 11809, 11850, 11851, 11862, 11876, 11929, 11939, 11940, 12002, 12002, 12027, 12070, 12075, 12084, 12113, 12126, 12140, 12187, 12273, 12282, 12295, 12334, 12346, 12375, 12396, 12405, 12414, 12443, 12452, 12460, 12460, 12462, 12465, 12476, 12544, 12548, 12572, 12574, 12581, 12583, 12648, 12672, 12681, 12710, 12748, 12758, 12764, 12791, 12853, 12899, 12916, 12926, 12951, 12956, 12956, 12960, 12968, 12984, 13059, 13106, 13141, 13169, 13190, 13199, 13203, 13210, 13228, 13231, 13252, 13295, 13327,  ...
